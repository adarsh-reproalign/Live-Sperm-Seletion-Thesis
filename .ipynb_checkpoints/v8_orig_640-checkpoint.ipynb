# %%
from ultralytics import YOLO

model = YOLO("yolov8x.pt")

model.train(
    data="Sperm-Detection-VISEM-1/data.yaml",   
    epochs=100,
    imgsz=640,
    batch=8,
    box=7.5,
    cls=0.5,
 
    project="runs/train",
    name="v8_orig_640"
)

print("Training completed!")
# Out:
# New https://pypi.org/project/ultralytics/8.4.46 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.45 🚀 Python-3.12.4 torch-2.11.0 CPU (Apple M2)
# ...
